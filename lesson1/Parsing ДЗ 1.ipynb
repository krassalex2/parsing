# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.
# https://api.github.com/users/USERNAME/repos

# %%
import requests
import json
from pprint import pprint

# %%
def get_json(url):
    response = requests.get(url)
    return response.json()

# %%
username = input('Input username: ')
url = 'https://api.github.com/users/'+username+'/repos'
json_repos = get_json(url)
pprint(json_repos)
# Out:
# Input username: krassalex2
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/krassalex2/basic_python/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/krassalex2/basic_python/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/krassalex2/basic_python/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/krassalex2/basic_python/branches{/branch}',
#   'clone_url': 'https://github.com/krassalex2/basic_python.git',
#   'collaborators_url': 'https://api.github.com/repos/krassalex2/basic_python/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/krassalex2/basic_python/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/krassalex2/basic_python/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/krassalex2/basic_python/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/krassalex2/basic_python/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/krassalex2/basic_python/contributors',
#   'created_at': '2022-02-12T08:59:39Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/krassalex2/basic_python/deployments',
#   'description': 'Python`s lessons',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/krassalex2/basic_python/downloads',
#   'events_url': 'https://api.github.com/repos/krassalex2/basic_python/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/krassalex2/basic_python/forks',
#   'full_name': 'krassalex2/basic_python',
#   'git_commits_url': 'https://api.github.com/repos/krassalex2/basic_python/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/krassalex2/basic_python/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/krassalex2/basic_python/git/tags{/sha}',
#   'git_url': 'git://github.com/krassalex2/basic_python.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/krassalex2/basic_python/hooks',
#   'html_url': 'https://github.com/krassalex2/basic_python',
#   'id': 458470277,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/krassalex2/basic_python/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/krassalex2/basic_python/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/krassalex2/basic_python/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/krassalex2/basic_python/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/krassalex2/basic_python/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/krassalex2/basic_python/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/krassalex2/basic_python/merges',
#   'milestones_url': 'https://api.github.com/repos/krassalex2/basic_python/milestones{/number}',
#   'mirror_url': None,
#   'name': 'basic_python',
#   'node_id': 'R_kgDOG1OzhQ',
#   'notifications_url': 'https://api.github.com/repos/krassalex2/basic_python/notifications{?since,all,participating}',
#   'open_issues': 8,
#   'open_issues_count': 8,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/97038468?v=4',
#             'events_url': 'https://api.github.com/users/krassalex2/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/krassalex2/followers',
#             'following_url': 'https://api.github.com/users/krassalex2/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/krassalex2/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/krassalex2',
#             'id': 97038468,
#             'login': 'krassalex2',
#             'node_id': 'U_kgDOBciwhA',
#             'organizations_url': 'https://api.github.com/users/krassalex2/orgs',
#             'received_events_url': 'https://api.github.com/users/krassalex2/received_events',
#             'repos_url': 'https://api.github.com/users/krassalex2/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/krassalex2/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/krassalex2/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/krassalex2'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/krassalex2/basic_python/pulls{/number}',
#   'pushed_at': '2022-03-11T21:03:09Z',
#   'releases_url': 'https://api.github.com/repos/krassalex2/basic_python/releases{/id}',
#   'size': 40,
#   'ssh_url': 'git@github.com:krassalex2/basic_python.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/krassalex2/basic_python/stargazers',
#   'statuses_url': 'https://api.github.com/repos/krassalex2/basic_python/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/krassalex2/basic_python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/krassalex2/basic_python/subscription',
#   'svn_url': 'https://github.com/krassalex2/basic_python',
#   'tags_url': 'https://api.github.com/repos/krassalex2/basic_python/tags',
#   'teams_url': 'https://api.github.com/repos/krassalex2/basic_python/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/krassalex2/basic_python/git/trees{/sha}',
#   'updated_at': '2022-02-12T08:59:39Z',
#   'url': 'https://api.github.com/repos/krassalex2/basic_python',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/krassalex2/python-libs/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/krassalex2/python-libs/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/krassalex2/python-libs/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/krassalex2/python-libs/branches{/branch}',
#   'clone_url': 'https://github.com/krassalex2/python-libs.git',
#   'collaborators_url': 'https://api.github.com/repos/krassalex2/python-libs/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/krassalex2/python-libs/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/krassalex2/python-libs/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/krassalex2/python-libs/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/krassalex2/python-libs/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/krassalex2/python-libs/contributors',
#   'created_at': '2022-06-20T21:54:17Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/krassalex2/python-libs/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/krassalex2/python-libs/downloads',
#   'events_url': 'https://api.github.com/repos/krassalex2/python-libs/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/krassalex2/python-libs/forks',
#   'full_name': 'krassalex2/python-libs',
#   'git_commits_url': 'https://api.github.com/repos/krassalex2/python-libs/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/krassalex2/python-libs/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/krassalex2/python-libs/git/tags{/sha}',
#   'git_url': 'git://github.com/krassalex2/python-libs.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/krassalex2/python-libs/hooks',
#   'html_url': 'https://github.com/krassalex2/python-libs',
#   'id': 505608837,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/krassalex2/python-libs/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/krassalex2/python-libs/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/krassalex2/python-libs/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/krassalex2/python-libs/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/krassalex2/python-libs/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/krassalex2/python-libs/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/krassalex2/python-libs/merges',
#   'milestones_url': 'https://api.github.com/repos/krassalex2/python-libs/milestones{/number}',
#   'mirror_url': None,
#   'name': 'python-libs',
#   'node_id': 'R_kgDOHiL6hQ',
#   'notifications_url': 'https://api.github.com/repos/krassalex2/python-libs/notifications{?since,all,participating}',
#   'open_issues': 5,
#   'open_issues_count': 5,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/97038468?v=4',
#             'events_url': 'https://api.github.com/users/krassalex2/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/krassalex2/followers',
#             'following_url': 'https://api.github.com/users/krassalex2/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/krassalex2/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/krassalex2',
#             'id': 97038468,
#             'login': 'krassalex2',
#             'node_id': 'U_kgDOBciwhA',
#             'organizations_url': 'https://api.github.com/users/krassalex2/orgs',
#             'received_events_url': 'https://api.github.com/users/krassalex2/received_events',
#             'repos_url': 'https://api.github.com/users/krassalex2/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/krassalex2/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/krassalex2/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/krassalex2'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/krassalex2/python-libs/pulls{/number}',
#   'pushed_at': '2022-07-22T20:49:41Z',
#   'releases_url': 'https://api.github.com/repos/krassalex2/python-libs/releases{/id}',
#   'size': 992,
#   'ssh_url': 'git@github.com:krassalex2/python-libs.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/krassalex2/python-libs/stargazers',
#   'statuses_url': 'https://api.github.com/repos/krassalex2/python-libs/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/krassalex2/python-libs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/krassalex2/python-libs/subscription',
#   'svn_url': 'https://github.com/krassalex2/python-libs',
#   'tags_url': 'https://api.github.com/repos/krassalex2/python-libs/tags',
#   'teams_url': 'https://api.github.com/repos/krassalex2/python-libs/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/krassalex2/python-libs/git/trees{/sha}',
#   'updated_at': '2022-06-20T21:54:17Z',
#   'url': 'https://api.github.com/repos/krassalex2/python-libs',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/krassalex2/ter-ver/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/krassalex2/ter-ver/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/krassalex2/ter-ver/branches{/branch}',
#   'clone_url': 'https://github.com/krassalex2/ter-ver.git',
#   'collaborators_url': 'https://api.github.com/repos/krassalex2/ter-ver/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/krassalex2/ter-ver/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/krassalex2/ter-ver/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/krassalex2/ter-ver/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/krassalex2/ter-ver/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/krassalex2/ter-ver/contributors',
#   'created_at': '2022-08-05T06:27:10Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/krassalex2/ter-ver/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/krassalex2/ter-ver/downloads',
#   'events_url': 'https://api.github.com/repos/krassalex2/ter-ver/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/krassalex2/ter-ver/forks',
#   'full_name': 'krassalex2/ter-ver',
#   'git_commits_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/tags{/sha}',
#   'git_url': 'git://github.com/krassalex2/ter-ver.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/krassalex2/ter-ver/hooks',
#   'html_url': 'https://github.com/krassalex2/ter-ver',
#   'id': 521528701,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/krassalex2/ter-ver/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/krassalex2/ter-ver/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/krassalex2/ter-ver/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/krassalex2/ter-ver/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/krassalex2/ter-ver/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/krassalex2/ter-ver/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/krassalex2/ter-ver/merges',
#   'milestones_url': 'https://api.github.com/repos/krassalex2/ter-ver/milestones{/number}',
#   'mirror_url': None,
#   'name': 'ter-ver',
#   'node_id': 'R_kgDOHxXlfQ',
#   'notifications_url': 'https://api.github.com/repos/krassalex2/ter-ver/notifications{?since,all,participating}',
#   'open_issues': 5,
#   'open_issues_count': 5,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/97038468?v=4',
#             'events_url': 'https://api.github.com/users/krassalex2/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/krassalex2/followers',
#             'following_url': 'https://api.github.com/users/krassalex2/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/krassalex2/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/krassalex2',
#             'id': 97038468,
#             'login': 'krassalex2',
#             'node_id': 'U_kgDOBciwhA',
#             'organizations_url': 'https://api.github.com/users/krassalex2/orgs',
#             'received_events_url': 'https://api.github.com/users/krassalex2/received_events',
#             'repos_url': 'https://api.github.com/users/krassalex2/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/krassalex2/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/krassalex2/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/krassalex2'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/krassalex2/ter-ver/pulls{/number}',
#   'pushed_at': '2022-10-20T19:35:13Z',
#   'releases_url': 'https://api.github.com/repos/krassalex2/ter-ver/releases{/id}',
#   'size': 26,
#   'ssh_url': 'git@github.com:krassalex2/ter-ver.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/krassalex2/ter-ver/stargazers',
#   'statuses_url': 'https://api.github.com/repos/krassalex2/ter-ver/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/krassalex2/ter-ver/subscribers',
#   'subscription_url': 'https://api.github.com/repos/krassalex2/ter-ver/subscription',
#   'svn_url': 'https://github.com/krassalex2/ter-ver',
#   'tags_url': 'https://api.github.com/repos/krassalex2/ter-ver/tags',
#   'teams_url': 'https://api.github.com/repos/krassalex2/ter-ver/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/trees{/sha}',
#   'updated_at': '2022-08-05T06:27:10Z',
#   'url': 'https://api.github.com/repos/krassalex2/ter-ver',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False}]

# %%
with open(f'{username}_repos.json', 'w') as f:
    json.dump(json_repos, f)

# %%
with open(f'{username}_repos.json', 'r') as f:
    data = json.load(f)
    pprint(data)
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/krassalex2/basic_python/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/krassalex2/basic_python/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/krassalex2/basic_python/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/krassalex2/basic_python/branches{/branch}',
#   'clone_url': 'https://github.com/krassalex2/basic_python.git',
#   'collaborators_url': 'https://api.github.com/repos/krassalex2/basic_python/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/krassalex2/basic_python/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/krassalex2/basic_python/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/krassalex2/basic_python/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/krassalex2/basic_python/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/krassalex2/basic_python/contributors',
#   'created_at': '2022-02-12T08:59:39Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/krassalex2/basic_python/deployments',
#   'description': 'Python`s lessons',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/krassalex2/basic_python/downloads',
#   'events_url': 'https://api.github.com/repos/krassalex2/basic_python/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/krassalex2/basic_python/forks',
#   'full_name': 'krassalex2/basic_python',
#   'git_commits_url': 'https://api.github.com/repos/krassalex2/basic_python/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/krassalex2/basic_python/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/krassalex2/basic_python/git/tags{/sha}',
#   'git_url': 'git://github.com/krassalex2/basic_python.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/krassalex2/basic_python/hooks',
#   'html_url': 'https://github.com/krassalex2/basic_python',
#   'id': 458470277,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/krassalex2/basic_python/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/krassalex2/basic_python/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/krassalex2/basic_python/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/krassalex2/basic_python/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/krassalex2/basic_python/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/krassalex2/basic_python/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/krassalex2/basic_python/merges',
#   'milestones_url': 'https://api.github.com/repos/krassalex2/basic_python/milestones{/number}',
#   'mirror_url': None,
#   'name': 'basic_python',
#   'node_id': 'R_kgDOG1OzhQ',
#   'notifications_url': 'https://api.github.com/repos/krassalex2/basic_python/notifications{?since,all,participating}',
#   'open_issues': 8,
#   'open_issues_count': 8,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/97038468?v=4',
#             'events_url': 'https://api.github.com/users/krassalex2/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/krassalex2/followers',
#             'following_url': 'https://api.github.com/users/krassalex2/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/krassalex2/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/krassalex2',
#             'id': 97038468,
#             'login': 'krassalex2',
#             'node_id': 'U_kgDOBciwhA',
#             'organizations_url': 'https://api.github.com/users/krassalex2/orgs',
#             'received_events_url': 'https://api.github.com/users/krassalex2/received_events',
#             'repos_url': 'https://api.github.com/users/krassalex2/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/krassalex2/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/krassalex2/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/krassalex2'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/krassalex2/basic_python/pulls{/number}',
#   'pushed_at': '2022-03-11T21:03:09Z',
#   'releases_url': 'https://api.github.com/repos/krassalex2/basic_python/releases{/id}',
#   'size': 40,
#   'ssh_url': 'git@github.com:krassalex2/basic_python.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/krassalex2/basic_python/stargazers',
#   'statuses_url': 'https://api.github.com/repos/krassalex2/basic_python/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/krassalex2/basic_python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/krassalex2/basic_python/subscription',
#   'svn_url': 'https://github.com/krassalex2/basic_python',
#   'tags_url': 'https://api.github.com/repos/krassalex2/basic_python/tags',
#   'teams_url': 'https://api.github.com/repos/krassalex2/basic_python/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/krassalex2/basic_python/git/trees{/sha}',
#   'updated_at': '2022-02-12T08:59:39Z',
#   'url': 'https://api.github.com/repos/krassalex2/basic_python',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/krassalex2/python-libs/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/krassalex2/python-libs/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/krassalex2/python-libs/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/krassalex2/python-libs/branches{/branch}',
#   'clone_url': 'https://github.com/krassalex2/python-libs.git',
#   'collaborators_url': 'https://api.github.com/repos/krassalex2/python-libs/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/krassalex2/python-libs/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/krassalex2/python-libs/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/krassalex2/python-libs/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/krassalex2/python-libs/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/krassalex2/python-libs/contributors',
#   'created_at': '2022-06-20T21:54:17Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/krassalex2/python-libs/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/krassalex2/python-libs/downloads',
#   'events_url': 'https://api.github.com/repos/krassalex2/python-libs/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/krassalex2/python-libs/forks',
#   'full_name': 'krassalex2/python-libs',
#   'git_commits_url': 'https://api.github.com/repos/krassalex2/python-libs/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/krassalex2/python-libs/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/krassalex2/python-libs/git/tags{/sha}',
#   'git_url': 'git://github.com/krassalex2/python-libs.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/krassalex2/python-libs/hooks',
#   'html_url': 'https://github.com/krassalex2/python-libs',
#   'id': 505608837,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/krassalex2/python-libs/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/krassalex2/python-libs/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/krassalex2/python-libs/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/krassalex2/python-libs/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/krassalex2/python-libs/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/krassalex2/python-libs/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/krassalex2/python-libs/merges',
#   'milestones_url': 'https://api.github.com/repos/krassalex2/python-libs/milestones{/number}',
#   'mirror_url': None,
#   'name': 'python-libs',
#   'node_id': 'R_kgDOHiL6hQ',
#   'notifications_url': 'https://api.github.com/repos/krassalex2/python-libs/notifications{?since,all,participating}',
#   'open_issues': 5,
#   'open_issues_count': 5,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/97038468?v=4',
#             'events_url': 'https://api.github.com/users/krassalex2/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/krassalex2/followers',
#             'following_url': 'https://api.github.com/users/krassalex2/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/krassalex2/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/krassalex2',
#             'id': 97038468,
#             'login': 'krassalex2',
#             'node_id': 'U_kgDOBciwhA',
#             'organizations_url': 'https://api.github.com/users/krassalex2/orgs',
#             'received_events_url': 'https://api.github.com/users/krassalex2/received_events',
#             'repos_url': 'https://api.github.com/users/krassalex2/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/krassalex2/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/krassalex2/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/krassalex2'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/krassalex2/python-libs/pulls{/number}',
#   'pushed_at': '2022-07-22T20:49:41Z',
#   'releases_url': 'https://api.github.com/repos/krassalex2/python-libs/releases{/id}',
#   'size': 992,
#   'ssh_url': 'git@github.com:krassalex2/python-libs.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/krassalex2/python-libs/stargazers',
#   'statuses_url': 'https://api.github.com/repos/krassalex2/python-libs/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/krassalex2/python-libs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/krassalex2/python-libs/subscription',
#   'svn_url': 'https://github.com/krassalex2/python-libs',
#   'tags_url': 'https://api.github.com/repos/krassalex2/python-libs/tags',
#   'teams_url': 'https://api.github.com/repos/krassalex2/python-libs/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/krassalex2/python-libs/git/trees{/sha}',
#   'updated_at': '2022-06-20T21:54:17Z',
#   'url': 'https://api.github.com/repos/krassalex2/python-libs',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/krassalex2/ter-ver/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/krassalex2/ter-ver/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/krassalex2/ter-ver/branches{/branch}',
#   'clone_url': 'https://github.com/krassalex2/ter-ver.git',
#   'collaborators_url': 'https://api.github.com/repos/krassalex2/ter-ver/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/krassalex2/ter-ver/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/krassalex2/ter-ver/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/krassalex2/ter-ver/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/krassalex2/ter-ver/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/krassalex2/ter-ver/contributors',
#   'created_at': '2022-08-05T06:27:10Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/krassalex2/ter-ver/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/krassalex2/ter-ver/downloads',
#   'events_url': 'https://api.github.com/repos/krassalex2/ter-ver/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/krassalex2/ter-ver/forks',
#   'full_name': 'krassalex2/ter-ver',
#   'git_commits_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/tags{/sha}',
#   'git_url': 'git://github.com/krassalex2/ter-ver.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/krassalex2/ter-ver/hooks',
#   'html_url': 'https://github.com/krassalex2/ter-ver',
#   'id': 521528701,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/krassalex2/ter-ver/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/krassalex2/ter-ver/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/krassalex2/ter-ver/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/krassalex2/ter-ver/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/krassalex2/ter-ver/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/krassalex2/ter-ver/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/krassalex2/ter-ver/merges',
#   'milestones_url': 'https://api.github.com/repos/krassalex2/ter-ver/milestones{/number}',
#   'mirror_url': None,
#   'name': 'ter-ver',
#   'node_id': 'R_kgDOHxXlfQ',
#   'notifications_url': 'https://api.github.com/repos/krassalex2/ter-ver/notifications{?since,all,participating}',
#   'open_issues': 5,
#   'open_issues_count': 5,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/97038468?v=4',
#             'events_url': 'https://api.github.com/users/krassalex2/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/krassalex2/followers',
#             'following_url': 'https://api.github.com/users/krassalex2/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/krassalex2/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/krassalex2',
#             'id': 97038468,
#             'login': 'krassalex2',
#             'node_id': 'U_kgDOBciwhA',
#             'organizations_url': 'https://api.github.com/users/krassalex2/orgs',
#             'received_events_url': 'https://api.github.com/users/krassalex2/received_events',
#             'repos_url': 'https://api.github.com/users/krassalex2/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/krassalex2/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/krassalex2/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/krassalex2'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/krassalex2/ter-ver/pulls{/number}',
#   'pushed_at': '2022-10-20T19:35:13Z',
#   'releases_url': 'https://api.github.com/repos/krassalex2/ter-ver/releases{/id}',
#   'size': 26,
#   'ssh_url': 'git@github.com:krassalex2/ter-ver.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/krassalex2/ter-ver/stargazers',
#   'statuses_url': 'https://api.github.com/repos/krassalex2/ter-ver/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/krassalex2/ter-ver/subscribers',
#   'subscription_url': 'https://api.github.com/repos/krassalex2/ter-ver/subscription',
#   'svn_url': 'https://github.com/krassalex2/ter-ver',
#   'tags_url': 'https://api.github.com/repos/krassalex2/ter-ver/tags',
#   'teams_url': 'https://api.github.com/repos/krassalex2/ter-ver/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/krassalex2/ter-ver/git/trees{/sha}',
#   'updated_at': '2022-08-05T06:27:10Z',
#   'url': 'https://api.github.com/repos/krassalex2/ter-ver',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False}]

# %% [markdown]
# 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
import requests
import json

appid = 'b6907d289e10d714a6e88b30761fae22'
service = 'https://samples.openweathermap.org/data/2.5/weather'
city = 'Stavropol'
url = f'{service}?q={city}&appid={appid}'
response = get_json(url)
print(response)

with open(f'{city}_weather.json', 'w') as f:
    json_repo = json.dump(response, f)
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 280.32, 'pressure': 1012, 'humidity': 81, 'temp_min': 279.15, 'temp_max': 281.15}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 80}, 'clouds': {'all': 90}, 'dt': 1485789600, 'sys': {'type': 1, 'id': 5091, 'message': 0.0103, 'country': 'GB', 'sunrise': 1485762037, 'sunset': 1485794875}, 'id': 2643743, 'name': 'London', 'cod': 200}
